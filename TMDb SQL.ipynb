# %%
import pandas as pd
import numpy as np
import pymysql
pymysql.install_as_MySQLdb()
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %%
# Basics df
basics = pd.read_csv('Data/title_basics.csv.gz')
basics.head()
# Out:
#       tconst titletype                                       primarytitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0088751     movie                                  The Naked Monster
# 4  tt0096056     movie                               Crime and Punishment
#
#                                originaltitle  isadult  startyear  endyear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                          The Naked Monster        0     2005.0      NaN
# 4                       Crime and Punishment        0     2002.0      NaN
#
#    runtimeminutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
# Dropping unneeded columns
basics = basics.drop(columns = ['titletype', 'originaltitle', 'isadult', 'endyear'])
basics.head()
# Out:
#       tconst                                       primarytitle  startyear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#    runtimeminutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
## create a col with a list of genres
basics['genres_split'] = basics['genres'].str.split(',')
basics
# Out:
#           tconst                                       primarytitle  \
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# 3      tt0088751                                  The Naked Monster
# 4      tt0096056                               Crime and Punishment
# ...          ...                                                ...
# 86708  tt9914942                             Life Without Sara Amat
# 86709  tt9915872                               The Last White Witch
# 86710  tt9916170                                      The Rehearsal
# 86711  tt9916190                                          Safeguard
# 86712  tt9916362                                              Coven
#
#        startyear  runtimeminutes                     genres  \
# 0         2001.0             118     Comedy,Fantasy,Romance
# 1         2020.0              70                      Drama
# 2         2018.0             122                      Drama
# 3         2005.0             100       Comedy,Horror,Sci-Fi
# 4         2002.0             126                      Drama
# ...          ...             ...                        ...
# 86708     2019.0              74                      Drama
# 86709     2019.0              97       Comedy,Drama,Fantasy
# 86710     2019.0              51                      Drama
# 86711     2020.0              95  Action,Adventure,Thriller
# 86712     2020.0              92              Drama,History
#
#                         genres_split
# 0         [Comedy, Fantasy, Romance]
# 1                            [Drama]
# 2                            [Drama]
# 3           [Comedy, Horror, Sci-Fi]
# 4                            [Drama]
# ...                              ...
# 86708                        [Drama]
# 86709       [Comedy, Drama, Fantasy]
# 86710                        [Drama]
# 86711  [Action, Adventure, Thriller]
# 86712               [Drama, History]
#
# [86713 rows x 6 columns]

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86713 entries, 0 to 86712
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          86713 non-null  object
#  1   primarytitle    86713 non-null  object
#  2   startyear       86713 non-null  float64
#  3   runtimeminutes  86713 non-null  int64
#  4   genres          86713 non-null  object
#  5   genres_split    86713 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.0+ MB

# %%
exploded_genres = basics.explode('genres_split')
exploded_genres
# Out:
#           tconst                                       primarytitle  \
# 0      tt0035423                                     Kate & Leopold
# 0      tt0035423                                     Kate & Leopold
# 0      tt0035423                                     Kate & Leopold
# 1      tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2      tt0069049                         The Other Side of the Wind
# ...          ...                                                ...
# 86711  tt9916190                                          Safeguard
# 86711  tt9916190                                          Safeguard
# 86711  tt9916190                                          Safeguard
# 86712  tt9916362                                              Coven
# 86712  tt9916362                                              Coven
#
#        startyear  runtimeminutes                     genres genres_split
# 0         2001.0             118     Comedy,Fantasy,Romance       Comedy
# 0         2001.0             118     Comedy,Fantasy,Romance      Fantasy
# 0         2001.0             118     Comedy,Fantasy,Romance      Romance
# 1         2020.0              70                      Drama        Drama
# 2         2018.0             122                      Drama        Drama
# ...          ...             ...                        ...          ...
# 86711     2020.0              95  Action,Adventure,Thriller       Action
# 86711     2020.0              95  Action,Adventure,Thriller    Adventure
# 86711     2020.0              95  Action,Adventure,Thriller     Thriller
# 86712     2020.0              92              Drama,History        Drama
# 86712     2020.0              92              Drama,History      History
#
# [161980 rows x 6 columns]

# %%
unique_genres = sorted(exploded_genres['genres_split'].unique())

# %%
# save tconst and genre split as new df
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0069049        Drama

# %%
basics = basics.drop(columns = 'genres_split')
basics.head()
# Out:
#       tconst                                       primarytitle  startyear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#    runtimeminutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
genre_id_map = dict(zip(unique_genres, range(len(unique_genres))))
genre_id_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
## make new integer genre_id and drop string genres
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns='genres_split')

# %%
genre_lookup = pd.DataFrame({'genre_name': genre_id_map.keys(),
                            'genre_id': genre_id_map.values()})
genre_lookup.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
# ratings df
ratings = pd.read_csv('Data/title_ratings.tsv.gz')
ratings.head()
# Out:
#       tconst  averagerating  numvotes
# 0  tt0000001            5.7      1972
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2615
# 3  tt0000006            5.1       181
# 4  tt0000007            5.4       818

# %%
# ratings df
tmdb = pd.read_csv('tmdb_results_combined.csv.gz')
tmdb.head()
# Out:
#      imdb_id  adult                     backdrop_path  \
# 0  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 1  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
# 2  tt0119273    0.0  /f5C03doOWiauu37bToKXtpgP5bS.jpg
# 3  tt0120263    0.0  /ynXVuylP8upazjz8lrqb1PEMkdR.jpg
# 4  tt0120467    0.0  /knok3mNReKqPTplnnqz7E4dd7mD.jpg
#
#                                belongs_to_collection      budget  \
# 0                                                NaN  10000000.0
# 1                                                NaN    150000.0
# 2  {'id': 141086, 'name': 'Heavy Metal Collection...  15000000.0
# 3                                                NaN         0.0
# 4                                                NaN    120000.0
#
#                                               genres homepage       id  \
# 0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN  62127.0
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN    843.0
# 2  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN  16225.0
# 3  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...      NaN  34070.0
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...      NaN  19085.0
#
#   original_language              original_title  ...     revenue  runtime  \
# 0                en             The Fantasticks  ...         0.0     86.0
# 1                cn                        花樣年華  ...  12854953.0     99.0
# 2                en            Heavy Metal 2000  ...         0.0     88.0
# 3                sv  Sånger från andra våningen  ...     80334.0     98.0
# 4                en                      Vulgar  ...     14904.0     87.0
#
#                                     spoken_languages    status  \
# 0  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 1  [{'english_name': 'Cantonese', 'iso_639_1': 'c...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Russian', 'iso_639_1': 'ru'...  Released
# 4  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#                                              tagline  \
# 0      Try to remember the first time magic happened
# 1  Feel the heat, keep the feeling burning, let t...
# 2  not to survive the fight in the external world...
# 3                                                NaN
# 4   Everyone loves a clown... some more than others.
#
#                          title  video  vote_average vote_count certification
# 0              The Fantasticks    0.0         5.500       22.0           NaN
# 1         In the Mood for Love    0.0         8.119     2203.0            PG
# 2             Heavy Metal 2000    0.0         6.091      181.0             R
# 3  Songs from the Second Floor    0.0         7.200      239.0           NaN
# 4                       Vulgar    0.0         5.500       44.0             R
#
# [5 rows x 26 columns]

# %%
# Dropping unneeded columns
tmdb = tmdb[['imdb_id', 'revenue', 'budget', 'certification']]
tmdb.head()
# Out:
#      imdb_id     revenue      budget certification
# 0  tt0113026         0.0  10000000.0           NaN
# 1  tt0118694  12854953.0    150000.0            PG
# 2  tt0119273         0.0  15000000.0             R
# 3  tt0120263     80334.0         0.0           NaN
# 4  tt0120467     14904.0    120000.0             R

# %%
connection = "mysql+pymysql://root:root@localhost/tmdb"
engine = create_engine(connection)

# %%
if database_exists(connection):
    print('It exists!')
else:
    create_database(connection)
    print('Database Created!')
# Out:
# It exists!

# %%
from sqlalchemy.types import *
## Calculate max string lengths for object columns
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primarytitle'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
df_schema = {"tconst": String(key_len+1), "primarytitle": Text(title_len+1),
             'startYear':Float(),'endYear':Float(),'runtimeminutes':Integer()}

# %%
# Save to sql with dtype and index=False
basics.to_sql('title_basics',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 86713

# %%
# Save to sql with dtype and index=False
ratings.to_sql('title_ratings',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 499319

# %%
# Save to sql with dtype and index=False
tmdb.to_sql('tmdb',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 637

# %%
# Save to sql with dtype and index=False
title_genres.to_sql('title_genres',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 161980

# %%
# Save to sql with dtype and index=False
genre_lookup.to_sql('genres_lookup',engine,dtype=df_schema,if_exists='replace',index=False)
# Out:
# 26

# %%
q = '''SELECT * FROM title_basics LIMIT 5;'''
pd.read_sql(q,engine)
# Out:
#       tconst                                       primarytitle  startyear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0088751                                  The Naked Monster     2005.0
# 4  tt0096056                               Crime and Punishment     2002.0
#
#    runtimeminutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             100    Comedy,Horror,Sci-Fi
# 4             126                   Drama

# %%
q = '''SELECT * FROM title_ratings LIMIT 5;'''
pd.read_sql(q,engine)
# Out:
#       tconst  averagerating  numvotes
# 0  tt0000001            5.7      1972
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2615
# 3  tt0000006            5.1       181
# 4  tt0000007            5.4       818

# %%
q = '''SELECT * FROM tmdb LIMIT 5;'''
pd.read_sql(q,engine)
# Out:
#      imdb_id     revenue      budget certification
# 0  tt0113026         0.0  10000000.0          None
# 1  tt0118694  12854953.0    150000.0            PG
# 2  tt0119273         0.0  15000000.0             R
# 3  tt0120263     80334.0         0.0          None
# 4  tt0120467     14904.0    120000.0             R

# %%
q = '''SELECT * FROM title_genres LIMIT 5;'''
pd.read_sql(q,engine)
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 1  tt0035423         9
# 2  tt0035423        18
# 3  tt0062336         7
# 4  tt0069049         7

# %%
q = '''SELECT * FROM genres_lookup LIMIT 5;'''
pd.read_sql(q,engine)
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
q = '''SHOW TABLES'''
pd.read_sql(q,engine)
# Out:
#   Tables_in_tmdb
# 0  genres_lookup
# 1  title.ratings
# 2   title_basics
# 3   title_genres
# 4  title_ratings
# 5           tmdb
